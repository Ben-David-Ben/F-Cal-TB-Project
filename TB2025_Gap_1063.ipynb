# %%
import numpy as np
import matplotlib.pylab as plt
import uproot
import awkward as ak
import seaborn
import RA_funcs as rf
from scipy.signal import find_peaks
# Out:
# imports work

# %% [markdown]
# <!-- <span style="font-family: arial; font-size:25px; color:pink">
#
# Open ROOT file and extract data -->

# %%
run_number = 1063

hit_data = rf.get_ROOT_data_zip(f"TB_FIRE_{run_number}_hits.root")
# Out:
# TB_FIRE_1063_hits.root finished

# %% [markdown]
# <!-- <span style="font-family: arial; font-size:25px; color:pink">
#
# Hit Counts and Amp in Single Planes -->

# %%
# rf.hits_amount_colormap_single_plane(hit_data, 7)

# %%
rf.hits_amount_colormap_single_plane(hit_data, 0)

# %% [markdown]
# <!-- <span style="font-family: arial; font-size:25px; color:pink">
#
# Shower Evolution Throughout the Sensor -->

# %%
# rf.single_event_evolution_amp(hit_data, 132119, cmap="managua", save = run_number)
# # rf.single_event_evolution_amp(hit_data, 132119, cmap="managua")

# %%
# plt.clf()   # Clear the current figure
# plt.close() # Close any open figures
# %matplotlib widget
# rf.amp_histo_single_plane(hit_data_1101,1)

# %%
# rf.amp_histo_single_plane_total_event(hit_data,0)

# %%
# rf.average_amp_vs_plane(hit_data)

# %%
# rf.plot_empty_first_planes(hit_data)

# %%
rf.event_shower_energy_vs_X_position(hit_data, single_pad_only = "true", specific_Y = 8)
# Out:
# 487424
# 487424
# 202314
# 202314

# %%
rf.Histo_shower_energy_for_X_position(hit_data, 5, single_pad_only = "true")
# Out:
# 10 29022
# ########
# 11 120836
# ########
# 12 123141
# ########
# 13 101011
# ########
# 14 103338
# ########

# %%
rf.avg_ENERGY_vs_plane_per_X_position(hit_data, 5, print_energies = "true")
# Out:
# [10 11 12 13 14]
# 10
# [np.float64(89.81234925229137), np.float64(324.1707544129758), np.float64(480.0374786446469), np.float64(599.165139532453), np.float64(433.59143699081295), np.float64(599.6051961100944), np.float64(682.1753534793457), np.float64(658.374965431416)]
# 11
# [np.float64(91.26789201893476), np.float64(297.6416503256531), np.float64(398.3425123191652), np.float64(522.9405515522931), np.float64(422.2867231873678), np.float64(489.0763977401908), np.float64(671.3698541275095), np.float64(574.6948997724744)]
# 12
# [np.float64(88.08103718501555), np.float64(244.28018898723158), np.float64(229.88193255036293), np.float64(517.1144778363375), np.float64(690.8228127374795), np.float64(537.6209726443769), np.float64(676.0801185489994), np.float64(562.2771355432)]
# 13
# [np.float64(90.73512785736207), np.float64(275.347443130505), np.float64(242.71073953360263), np.float64(564.980713132913), np.float64(660.5654693739357), np.float64(612.1864749056913), np.float64(746.7741909819599), np.float64(614.3031073418275)]
# 14
# [np.float64(95.54574309547311), np.float64(282.1206201068077), np.float64(307.34135601269236), np.float64(573.2954400806823), np.float64(790.8971198223987), np.float64(620.6477224905312), np.float64(749.9055362884815), np.float64(622.2720392758039)]
