# %%
import numpy as np
import matplotlib.pylab as plt
import uproot
import awkward as ak
import seaborn
import RA_funcs as rf
from scipy.signal import find_peaks
# Out:
# imports work

# %% [markdown]
# <!-- <span style="font-family: arial; font-size:25px; color:pink">
#
# Open ROOT file and extract data -->

# %%
run_number = 1063

hit_data = rf.get_ROOT_data_zip(f"TB_FIRE_{run_number}_hits.root")
# Out:
# TB_FIRE_1063_hits.root finished

# %% [markdown]
# <!-- <span style="font-family: arial; font-size:25px; color:pink">
#
# Hit Counts and Amp in Single Planes -->

# %%
# rf.hits_amount_colormap_single_plane(hit_data, 7)

# %%
rf.hits_amount_colormap_single_plane(hit_data, 0)

# %% [markdown]
# <!-- <span style="font-family: arial; font-size:25px; color:pink">
#
# Shower Evolution Throughout the Sensor -->

# %%
# rf.single_event_evolution_amp(hit_data, 132119, cmap="managua", save = run_number)
# # rf.single_event_evolution_amp(hit_data, 132119, cmap="managua")

# %%
# plt.clf()   # Clear the current figure
# plt.close() # Close any open figures
# %matplotlib widget
# rf.amp_histo_single_plane(hit_data_1101,1)

# %%
# rf.amp_histo_single_plane_total_event(hit_data,0)

# %%
# rf.average_amp_vs_plane(hit_data)

# %%
# rf.plot_empty_first_planes(hit_data)

# %%
rf.event_shower_energy_vs_X_position(hit_data, single_pad_only = "true")

# %%
rf.avg_ENERGY_vs_plane_per_X_position(hit_data, 5, print_energies = "true")
# Out:
# [10 11 12 13 14]
# 10
# [np.float64(162.75233385272), np.float64(355.3045205114171), np.float64(485.9553367378608), np.float64(629.096884108543), np.float64(463.27041616117555), np.float64(597.3342020369927), np.float64(696.9778280481323), np.float64(635.5604743835598)]
# 11
# [np.float64(131.50843044173754), np.float64(312.550333552056), np.float64(397.1205578769682), np.float64(553.9669722070387), np.float64(473.3209148453984), np.float64(517.1158436468758), np.float64(683.6409026343312), np.float64(581.2554207229016)]
# 12
# [np.float64(140.32580291663155), np.float64(286.90827477025255), np.float64(264.11845780238986), np.float64(580.946994289825), np.float64(718.5194413323037), np.float64(581.7198005579957), np.float64(710.7903914939925), np.float64(585.5785883180671)]
# 13
# [np.float64(149.14010819392584), np.float64(313.80347749475266), np.float64(282.8210657587613), np.float64(624.085734367498), np.float64(723.1088150331759), np.float64(641.8777201336802), np.float64(762.6316416382421), np.float64(621.2250448458042)]
# 14
# [np.float64(135.71057778326187), np.float64(306.3511741644486), np.float64(319.75286597320553), np.float64(608.4668262248898), np.float64(811.4909476978096), np.float64(636.9953391561958), np.float64(757.792018433294), np.float64(622.7873683038338)]
