# %%
import numpy as np
import matplotlib.pylab as plt
import uproot
import awkward as ak
import seaborn
import RA_funcs as rf
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
from scipy.special import gamma
from scipy.stats import skew
import Scope_funcs as sf
# Out:
# imports work
# imports work

# %% [markdown]
# <span style="font-family: arial; font-size:25px; color:pink">
#
# Open ROOT file and extract data

# %%
run_number = 1079

hit_data = rf.get_ROOT_data_zip_RECO(run_number)
# Out:
# 1079 RECONSTRUCTED finished

# %% [markdown]
# <span style="font-family: arial; font-size:25px; color:pink">
#
# Hit Counts and Amp in Single Planes

# %%
rf.hits_amount_colormap_single_plane(hit_data, 1, inverse_plane_order=True)

# %%
rf.hits_amount_colormap_single_plane(hit_data, 0)

# %% [markdown]
# <span style="font-family: arial; font-size:25px; color:pink">
#
# Shower Evolution Throughout the Sensor

# %%
# rf.single_event_evolution_amp(hit_data, 54106, cmap="managua")

# %%
# plt.clf()   # Clear the current figure
# plt.close() # Close any open figures
# %matplotlib widget
# rf.amp_histo_single_plane(hit_data_1101,1)

# %%
# rf.amp_histo_single_plane_total_event(hit_data,0)

# %%
# rf.average_amp_vs_plane(hit_data)

# %%
rf.plot_empty_first_planes(hit_data)
# Out:
# total percentage of events: 100.00000000000001
# c:\Users\bents\Desktop\Personal\work\Halina\F-Cal-TB-project\RA_funcs.py:544: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
